# %% [markdown]
# # <span style="color:teal">4.0: Basic Loops </span>
# In this notebook you will learn how to:
#    -  **Learn how to write a while & for loops**
#    -  **Utilize that knowledge to write functions that use loops to parse through information iteratively**

# %% [markdown]
# ## <span style = "color:blue">*Section 1: Using While loops*</span>
# - In this section you will see a simple example of a while loop, and apply that knowledge to write various other while loops.

# %%
# A very simple loop that executes 10 times. 0 TO 10
counter = 0
while counter < 10:
    counter += 1

# %% [markdown]
# ### <span style="color:green">Note: While True loop</span>
# - This is a very dangerous loop. It is set to run forever as True is always True! It can be useful in rare contexts

# %%
#Break statements get you out of whatever loop you are in
while True:
    if input("Please enter e to exit: ").lower() == "e":
        break #break will get you out of a loop
# Out:
# Please enter e to exit: e

# %% [markdown]
# ### <span style="color:green">Note: How to handle the dreaded infinite loop</span>
# - If the notebook is stuck in an infinite loop, don't panic!
# - Go to Kernel > Interrupt

# %% [markdown]
# ##  <span style = "color:red">ACTIVITY 1: While loop practice </span>
# - Pay close attention to what each loop says to do. 'to' typically means < or >, while 'through' typically means <= or >=
#
#
# - **1) Write a while loop that counts down from 10 to 0**
# - **3) Write a while loop that counts the number of even numbers from 0 to 10**
# - **4) Write a while loop that counts the number of odd numbers from 0 to 957**
# - **5) Write a while loop that prints numbers which are divisible by 7, between between 1500 and 2700 (both included).** HINT: Use Modulo
# - **6) Write a while loop that will cancel once the user enters an 'E'**

# %% [markdown]
# ### <span style="color:green">Note: Statistical Simulation </span>
# - Below is an example of using a loop to run a statistical simulation
# - The code is examining the difference between rolling 1 twelve-sided die vs rolling 2 six-sided die
# - It utilizes the random class to generate random numbers within a particular range
# - It loops 'tries' number of times, adding up all the randomly generated numebrs for each die
# - Then calculates the average of each by dividing by tries
# - The use of the 'time' class is to demonstrate how quickly python can operate
# - It grabs the time at the start and end, and calculates how long the function took to operate by getting the difference between the two times

# %%
import time
import random

# %%
def diceTest(tries):
    #initialize all the vars
    counter = 0

    twelveDieCount = 0
    twoSixDieCount = 0

    start = time.time() #Grab time at the beginning

    while counter < tries:
        dice1 = random.randint(1,12)
        dice2 = random.randint(1,6)
        dice3 = random.randint(1,6)
        diceTotal = dice2 + dice3

        twelveDieCount += dice1
        twoSixDieCount += diceTotal

        #print("One \'12 sided die: \'", dice1)
        #print("Two \'6 sided die\'", diceTotal,"\n")
        counter += 1

    print("Average for One  \'12 sided die: \'", twelveDieCount/(tries))
    print("Average for Two \'6 sided die\'", twoSixDieCount/tries)

    end = time.time() #Grab time at the end
    print("As a computer, this took me %.2f seconds to do that %.0f times, let's see YOU try and do that..." % ((end - start),  tries))

# %%
diceTest(10000000) #This is a billion tries
# Out:
# Average for One  '12 sided die: ' 6.4999625
# Average for Two '6 sided die' 7.0008943
# As a computer, this took me 20.62 seconds to do that 10000000 times, let's see YOU try and do that...

# %% [markdown]
# ## <span style = "color:blue">*Section 2: Using For Loops*</span>
# In this section you will learn how to:
#    -  **Learn how to write a for loop to traverse a number range**
#    -  **Learn how to write a for loop to traverse a string**
#    -  **Apply this knowledge to search and track for values across a fixed dataset*

# %% [markdown]
# ### <span style="color:green">Note: Range function</span>
# - The range function has 3 parameters
# - range(start,end,step)
# - Common in programming, the start parameter is inclusive and the end parameter is exclusive
# - Pay attention to each cell, as they demonstrate different variations and default values for the range function

# %%
#Here, i is set to the values of the range. i is 0, 1, 2, 3, 4 at each stage of the loop
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#There are default values if you leave it blank
for i in range(5): #first value is default of 0
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#There is a 3rd parameter of 'step' -- How many do you want to go by each time. It defaults to 1
for i in range(0,5,2):
    print(i)
# Out:
# 0
# 2
# 4

# %%
#You can also go backwards
for i in range(25,5,-5): #-5 means go back in the sequence by 5
    print(i)
# Out:
# 25
# 20
# 15
# 10

# %% [markdown]
# ## <span style = "color: red">ACTIVITY 1: Writing for loops to traverse numerical dataset</span>
# - **1)Write a for loop that prints the sequence of values from 0 to 8**
# - **2)Write a for loop that adds the sum of all even numbers in the sequence of values 0 to 20**
# - **3)Write a for loop that adds the sum of every 7th value in the sequence of numbers 567 to 100000**
# - **4.Write a for loop that prints every 12th value in the sequence of numbers 898 to 12 (be sure to COUNT DOWN)**

# %% [markdown]
# ## <span style = "color:blue">*Section 2: Traversing strings using for loops*</span>
# - In this section, you will learn about using a for loop to traverse a string using the 'in' operator
# - This is a very powerful statement that sets the variable you create to each element in the string

# %%
myName = "Ted Lasso"
for character in myName: #Using 'in' context of for loop
    print("Character: " + character)
# Out:
# Character: T
# Character: e
# Character: d
# Character:
# Character: L
# Character: a
# Character: s
# Character: s
# Character: o

# %% [markdown]
# ### <span style="color:green">Note: Extracting information through a search</span>
# - Below, I am using a for loop to grab the first name of an individual
# - It adds each character to the new variable firstName
# - When it comes across a space, it stops the loops using a break statement

# %%
myName = "Ted Lasso"
firstName = ""

for character in myName: #another use of 'in'
    if character == " ": #once we hit the space, stop
        break
    firstName += character

print("firstName: " + firstName)
# Out:
# firstName: Ted

# %% [markdown]
# ### <span style="color:green">Note: Extracting information through a search</span>
# - Below, I am writing a function that takes in a word and a letter and returns how many times that letter appears in the word.
# - To do so, I use a for loop to iterate through the string
# - Then increment a counter each time the current letter matches the letter we are trying to count
# - When the loop is done, function returns the count

# %%
def countOccurences(letterToCount, word):
    count = 0
    for letter in word:
        if letter == letterToCount:
            count += 1
    return count

# %%
countOccurences('a',"Obamna")
# Out:
# 2

# %% [markdown]
# ### <span style="color:green">Note: Using indexes of a string</span>
# - Every character in a string is associated with a number. We call this it's 'index'
# - **important to note** indexes start at 0. For example the string "Hello":
# - H e l l o - the values
# - 0 1 2 3 4 - the indexes
# - To access a value at it's index, you can use brackets [], see example in Python code below

# %%
s = "Hello"
print("s:", s)
print("s[0]:",s[0])
print("s[2:",s[2])
print("s[len(s) - 1]:",s[len(s) - 1]) #last value
print("s[-1]:",s[-1]) #shorthand way of saying last value
print("s[-2]",s[-2]) #second to last value
# Out:
# s: Hello
# s[0]: H
# s[2: l
# s[len(s) - 1]: o
# s[-1]: o
# s[-2] l

# %%
s = "Hello There"
print("s:", s)
print("s[4]:",s[4])
print("s[5]:",s[5]) # Space is a character
print("s[6]:",s[6])
# Out:
# s: Hello There
# s[4]: o
# s[5]:
# s[6]: T

# %%
#iterating over a string using the indexes:
s = "Yoda"
for i in range(len(s)):
    print(s[i])
# Out:
# Y
# o
# d
# a

# %% [markdown]
# # <span style="color:magenta">The Assignment: String Parsing Functions </span>
#
# - **1) Write a function called every_other_letter(s) that returns a new string containing every other character of a string**
#     - This function has 1 parameter: A String to print get other character of
#     - It returns a new string containing every other letter from the string s starting at the first letter
#     - Examples:
#       - every_other_letter("Hello") -> "Hlo"
#       - every_other_letter("Jump") -> "Jm"
#
# <br>
#
# - **2) Write a function that returns a string that contains all the characters of a given string through the first occurence of given character**.
#     - This function has two parameters: A string to create a substring from, and a terminating character
#     - EX:
#         - sub_str("hello", 'l') -> "hel"
#     - If terminating character not present, return message "Terminating Character not Found"
#     - Function should be case insensitive in regards to the terminating character
#
# <br>
#
# - **3) Write a function called count_vowels(s) that returns a count of all the vowels of a string**
#     - This function has 1 parameter: A string to count the vowels of
#     - For y, you must consider the following rules (from google):
#     - Y acts as a vowel when it is at the
#         - end of a word or syllable,
#         - in the middle of a syllable,
#         - when there are no other vowels present in the word.
#         - Examples include "gym," "cry," and "baby.

# %%
#PLACE YOUR CODE IN THESE FUNCTIONS
def every_other_letter(s):
    return ""
    
def sub_string(s, terminator):
    return ""

def count_vowels(s):
    return 0

# %%
#This testing framework was built by Google Gemini and Edited by Mr. Mazzia. Saved me a lot of tedius work! A great use of AI
#Run this to test the full coverage of your code!

import unittest

class TestStringFunctions(unittest.TestCase):
    
    # --- Tests for every_other_letter(s) ---
    def test_every_other_letter_empty(self):
        self.assertEqual(every_other_letter(""), "")
        
        
    def test_every_other_letter_single_char(self):
        self.assertEqual(every_other_letter("A"), "A")
        
    
    def test_every_other_letter_even_length(self):
        self.assertEqual(every_other_letter("abcd"), "ac")
        
        
    def test_every_other_letter_odd_length(self):
        self.assertEqual(every_other_letter("abcde"), "ace")
        
        
    # --- Tests for sub_string(s, terminator) ---
    def test_sub_string_terminator_not_found(self):
        # z not in
        self.assertEqual(sub_string("hello", "z"), "Terminating Character not Found")
        
    def test_sub_string_terminator_case_mismatch(self):
        # 'L' should get sent to lower case and pass
        self.assertEqual(sub_string("hello", "L"), "hel")

    def test_sub_string_terminator_at_start(self):
        #first string sub string
        self.assertEqual(sub_string("hello", "h"), "h")
        
    def test_sub_string_terminator_in_middle(self):
        self.assertEqual(sub_string("hello", "l"), "hel")
        
    def test_sub_string_terminator_at_end(self):
        self.assertEqual(sub_string("hello", "o"), "hello")
        
    def test_sub_string_case_insensitive_match(self):
        # 'L' is in the string at the end. The loop match is case-insensitive, 
        # so it will stop at the first 'l'.
        self.assertEqual(sub_string("helLoL", "L"), "hel")
        
    def test_sub_nothing(self):
        #test with nothing.
        self.assertEqual(sub_string("", "L"), "Terminating Character not Found")    
        
    # --- Tests for count_vowels(s) ---
    def test_count_vowels_empty(self):
        self.assertEqual(count_vowels(""), 0)
        
    def test_count_vowels_basic_only(self):
        self.assertEqual(count_vowels("audio"), 4) # a, u, i, o
        
    def test_count_vowels_no_vowels(self):
        self.assertEqual(count_vowels("bcd"), 0)
        
    def test_count_vowels_y_as_only_vowel(self):
        # y is a vowel because basic count is 0
        self.assertEqual(count_vowels("rhythm"), 1)
        
    def test_count_vowels_y_at_start(self):
        # y_loc == 0
        self.assertEqual(count_vowels("yellow"), 3) # y, e, o
        
    def test_count_vowels_y_at_end(self):
        # 'y' == s[-1]
        self.assertEqual(count_vowels("boy"), 2) # o, y
        
    def test_count_vowels_y_surrounded_by_consonants(self):
        # s[y_loc - 1] not in vowels and s[y_loc + 1] not in vowels
        self.assertEqual(count_vowels("sylvan"), 2) # y, a
        
    def test_count_vowels_y_adjacent_to_vowel(self):
        # y adjacent to basic vowel should not be counted
        self.assertEqual(count_vowels("saying"), 2) # a, i
        
    def test_count_vowels_y_double(self):
        # y adjacent to basic vowel should not be counted
        self.assertEqual(count_vowels("dryly"), 2) # y, y
        
# Run the tests directly in the Jupyter Notebook
if __name__ == '__main__':
    unittest.main(argv=[''], exit=False)
# Out:
# F..FFFFFF.FFFFFFFFFF
# ...
# FAIL: test_count_vowels_basic_only (__main__.TestStringFunctions.test_count_vowels_basic_only)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\cmazzia\AppData\Local\Temp\ipykernel_9536\2699935393.py", line 58, in test_count_vowels_basic_only
#     self.assertEqual(count_vowels("audio"), 4) # a, u, i, o
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 0 != 4
#
# ...
# FAIL: test_count_vowels_y_adjacent_to_vowel (__main__.TestStringFunctions.test_count_vowels_y_adjacent_to_vowel)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\cmazzia\AppData\Local\Temp\ipykernel_9536\2699935393.py", line 81, in test_count_vowels_y_adjacent_to_vowel
#     self.assertEqual(count_vowels("saying"), 2) # a, i
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 0 != 2
#
# ...

# %% [markdown]
# ## Submission Details
# - When done, go to 'File' > 'Save and Checkpoint'. This saves the file
# - Submit this Ipython Notebook on Google Classroom!
