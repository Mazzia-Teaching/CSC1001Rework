# %% [markdown]
# # <span style="color:teal">3.1: Data Structures </span>
# In this notebook you will learn how to:
#    -  **Create and access lists and tuples**
#    -  **Use list methods to modify lists**
#    -  **Use slicing to seperate lists**
#    -  **Traverse lists using a for loop**
#    -  **Use data structures to create a randomized pair-seating guide**

# %% [markdown]
# ## <span style = "color:blue">*Section 1: Tuples*</span>
# - This section will introduce you to the tuple data structure
# - Tuples are an immutable ways of grouping variables
# - They work the same way as lists, but they can't be modified after creation
# - Because they can't be changed, they are more space effiecient than a list
# - They are best used when you are creating a fixed a structure of variables

# %% [markdown]
# ### <span style="color:green">Note: Tuple Creation And Access</span>
# - To create a tuple, you use ( ), with each value being seperated by a comma.
# - To access the values directly, you can use the [] with the apropriate index
# - Or, you can 'unpack' the values as shown in the 3rd cell below

# %%
#Creating a Tuple of floats
coordinate = (0.0,1.0)

# %%
#Accessing
print("X:", coordinate[0]) #index starts at 0
print("Y:", coordinate[1])
# Out:
# X: 0.0
# Y: 1.0

# %%
#Unpacking values
x,y = coordinate
print("X:",x)
print("Y:",y)
# Out:
# X: 0.0
# Y: 1.0

# %%
#Tuples can contain any number of values, of varying datatypes
coordinate = (0.0,1.0,1.0,2.0)
x,y,z,w = coordinate
print("X:", x, " Y:", y, " Z:", z, " W:",w)
# Out:
# X: 0.0  Y: 1.0  Z: 1.0  W: 2.0

# %% [markdown]
# ### <span style="color:green">Note: Immutable Nature of Tuples</span>
# - Above, you are seeing an example of re-assigning the variable to a new tuple.
# - Below, you will see what happens if you try to modify a value of a tuple.

# %%
coordinate[1] = 5.0 #generates error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 coordinate[1] = 5.0
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## <span style = "color:blue">*Section 2: Lists*</span>
# - This section will introduce you to the list data structure
# - Lists are mutable
# - Lists have many methods you can use with them
# - They are best used when the data that is being grouped may change over time, or there will be data added over time

# %% [markdown]
# ### <span style="color:green">Note: List Creation And Access</span>
# - To create a tuple, you use [], with each value being seperated by a comma.
# - To access the values directly, you can use the [] with the apropriate index
# - To access from the back of the list, use a '-' in front of the index inside the []
# - To add to the end of list, use append(element)
# - To insert at a specific index, use insert(index,element). This shifts the current item at the index and the subsequent items to the right by 1

# %%
#Intialize list
heros = ["Steven", "Garnet", "Peridot", "Pearl"]

#Access the values
print(heros[0])
print(heros[1])
print(heros[2])
print(heros[3])
# Out:
# Steven
# Garnet
# Peridot
# Pearl

# %%
#Replacing an element
heros[3] = "Amethyst"
print(heros)
# Out:
# ['Steven', 'Garnet', 'Peridot', 'Amethyst']

# %%
#adding an element
heros.append("Pearl")
print(heros)
# Out:
# ['Steven', 'Garnet', 'Peridot', 'Amethyst', 'Pearl']

# %%
#Inserting an element
heros.insert(1,'Onion')
print(heros)
# Out:
# ['Steven', 'Onion', 'Garnet', 'Peridot', 'Amethyst', 'Pearl']

# %%
#Accessing from the back of list
print(heros[-1])
print(heros[-2])
# Out:
# Pearl
# Amethyst

# %% [markdown]
# ### <span style="color:green">Note: Accessing an invalid index</span>
# - Below demonstrates what happens if you access an index outside the bounds of the list

# %%
heros[6] #generates an error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 heros[6]
#
# IndexError: list index out of range

# %% [markdown]
# ## <span style = "color:blue">*Section 3: List Slicing*</span>
# - In this section, you will learn how to use slicing to extract values from a list
# - List slicing is an easy and efficient tool to extract values from a list.
# - Slicing uses [start:end:step] format, with each having default values. See Lecture 12 slide 7 for more info
# - Slicing does not modify the list, it returns a new list containing the sliced values

# %%
heros = ['Steven', 'Onion', 'Garnet', 'Peridot', 'Amethyst', 'Pearl']
print(heros)
print("Length of heros: ", len(heros)) #Gets the length of the list
# Out:
# ['Steven', 'Onion', 'Garnet', 'Peridot', 'Amethyst', 'Pearl']
# Length of heros:  6

# %%
print(heros[0:2]) #Slicing elements 0 to 2
# Out:
# ['Steven', 'Onion']

# %%
print(heros[0:1])
print(heros[1:]) #second parameter defaults to end of list if left blank
print(heros[0:len(heros):2]) #Go from 0, to the end, going every other
print(heros[::2]) #First defaults to 0, second to end of list, go by 2 (shorthand of saying the statement directly above)
print(heros[-2:]) #Slice the last 2 values
# Out:
# ['Steven']
# ['Onion', 'Garnet', 'Peridot', 'Amethyst', 'Pearl']
# ['Steven', 'Garnet', 'Amethyst']
# ['Steven', 'Garnet', 'Amethyst']
# ['Amethyst', 'Pearl']

# %% [markdown]
# ### <span style="color:green">Note: Slicing a string</span>
# - Strings work very similar to lists, but they are immutable
# - You can slice them to!

# %%
name = "Lobos"
print(name[0:3]) #Slicing string
# Out:
# Lob

# %% [markdown]
# ## <span style = "color:blue">*Section 4: Additional List Methods*</span>
# - In this section, you will learn how to use more list methods

# %% [markdown]
# ## Lists can do a lot more, here is a few things
#     To read up about all the different things lists can do:
# [https://www.programiz.com/python-programming/methods/list]

# %%
print("Pre-sort: ", heros)
heros.sort() #sorting
print("Sorted: ", heros)
heros.sort(reverse=True) #sort in reverse
print("Reverse Sorted: ",heros)
# Out:
# Pre-sort:  ['Steven', 'Onion', 'Garnet', 'Peridot', 'Amethyst', 'Pearl']
# Sorted:  ['Amethyst', 'Garnet', 'Onion', 'Pearl', 'Peridot', 'Steven']
# Reverse Sorted:  ['Steven', 'Peridot', 'Pearl', 'Onion', 'Garnet', 'Amethyst']

# %% [markdown]
# ## <span style = "color:blue">*Mathematical List Functions*</span>
#     - sum()
#     - len()
#     - min()
#     - max()

# %%
l = [5,10,-10,20]
print("sumof list :", sum(l)) #adds all the numbers
print("length of list:", len(l)) #how many items are in the list
print("min value of list:", min(l)) #min value
print("max value of list:", max(l)) #max value
# Out:
# sumof list : 25
# length of list: 4
# min value of list: -10
# max value of list: 20

# %% [markdown]
# ## <span style = "color:blue">*Section 5: Traversing Lists*</span>
# - In this section, you will learn how to use for loops to traverse a list
# - See Lecture 12, slide 17 for detailed information on list traversal

# %% [markdown]
# ### <span style="color:green">Note: Loop using indexes</span>
# - Indexes range from 0 to the length of the list - range(6) === range(0,6). A nice shorthand
# - Use the index to access the values

# %%
for index in range(len(heros)):
    print(index,heros[index])
# Out:
# 0 Steven
# 1 Peridot
# 2 Pearl
# 3 Onion
# 4 Garnet
# 5 Amethyst

# %% [markdown]
# ### <span style="color:green">Note: Loop using value</span>
# - The hero variable is set to each of the values in heros
# - The variable name can be anything, but is easy to understand as the singular value from a plural list name

# %%
for hero in heros:
    print(hero)
# Out:
# Steven
# Peridot
# Pearl
# Onion
# Garnet
# Amethyst

# %% [markdown]
# ### <span style="color:green">Note: Loop using both</span>
# - Enumerate generates a tuple pairs of index, value

# %%
for index,hero in enumerate(heros):
    print(index,hero)
# Out:
# 0 Steven
# 1 Peridot
# 2 Pearl
# 3 Onion
# 4 Garnet
# 5 Amethyst

# %% [markdown]
# ### <span style="color:green">Note: Use loop to extract values meeting a threshold</span>

# %%
scores = [95, 90, 85, 48, 90, 40, 46, 57, 98]
passingScores = []
for score in scores:
    if score >= 70:
        passingScores.append(score)
print("PassingScores:", passingScores)
print("Passing Ratio: %.2f" % (len(passingScores)/float(len(scores))))
# Out:
# PassingScores: [95, 90, 85, 90, 98]
# Passing Ratio: 0.56

# %% [markdown]
# ### <span style="color:green">Note: Use List Comprehension to extract values meeting a threshold</span>
# - List comprehension condenses the above for loop into 1 statement.
# - For more info, See Lecture 12, slide 20.
# - The way this reads:
#     - I want each score, for each score contained in scores, if that score is above 70.

# %%
scores = [95, 90, 85, 48, 90, 40, 46, 57, 98]
passingScores = [score for score in scores if score >= 70]
print("PassingScores:", passingScores)
# Out:
# PassingScores: [95, 90, 85, 90, 98]

# %% [markdown]
# ###  <span style = "color:red">ACTIVITY 1: Using loops to iterate through data structures</span>
# - **1) Write a loop that prints each value of words**
# - **2) Write a loop that prints the index and then value on the same line of each item in your words list**
# - **3) Write a loop that will print the values of only the odd indexes of a list**
# - **4) Write a loop that calculates the sum of all the lengths of the words in your words list**
# - **5) Calculate the average word length for your words list using the sum calculated above**

# %% [markdown]
# # <span style="color:teal">Section 6: Dictionaries </span>

# %% [markdown]
# ## <span style = "color:blue">*Section 1: Creating and Accessing Dictionaries*</span>
# - This section will introduce you to the dictionary data structure
# - Dictionaries are defined using the { }
# - They are hashed key - value maps with an instant lookup times.
# - Dictionary values are access via [ ] operator
# - For more detail, see Lecture 12 Slides 10-13

# %%
studentScores = {"Tina" : 80, "Louise" : 65, "Gene" : 68} #initializing dict
print(studentScores["Tina"]) #Access via the key

# %%
studentScores["Gene"] = 70 #overwrites value
studentScores["Tammy"] = 60 #creates new value
print(studentScores)

# %% [markdown]
# ## <span style = "color:blue">*Section 2: Traversing Dictionaries*</span>
# - This section will introduce you to traversing dictionaries using a for loop
# - For more info, go to Lecture 12, Slide 18

# %% [markdown]
# ### <span style="color:green">Note: Traverse using key-value pairs</span>
# - To get the key and value through iterations, use .items().
# - This turns the key-value pairs into a list of tuples
# - This is the most common way to iterate through a dict - it gives you both and you can choose to use or not use whatever you want!

# %%
#Using Key-Value Pairs
for key,value in studentScores.items():
    print(key, value)

# %% [markdown]
# ### <span style="color:green">Note: Use Dictionary Comprehension</span>
# - Comprehension reduces the above loop and if statement into one statement
# - For more info, see Lecture 12, Slide 21
# - This reads:
#     - I want each name score pair, for each name score pair in the dictionary, if the score is >= 70

# %%
studentScores = {"Tina" : 75, "Louise" : 65, "Gene" : 70, "Tammy" : 95}
passingStudents = {name:score for name,score in studentScores.items() if score >= 70}
passingStudents
# Out:
# {'Tina': 75, 'Gene': 70, 'Tammy': 95}

# %% [markdown]
# ###  <span style = "color:red">ACTIVITY 1: Iterating through a dictionary</span>
# - **1) Create a dictionary with 3 entries. The keys & values can be set to whatever you like**
# - **2) Write a loop that prints out all the keys in that dictionary**
# - **3) Write a loop that prints out all the values in that dictionary**
# - **4) Write a loop that prints out all the key-value pairs in that dictionary**
# - **5) Write a loop that prints out all the key-value pairs that meet a certain condition**

# %% [markdown]
# # <span style="color:magenta">The Assignment: Sorting Data </span>
# - In this assignment, you will be given disjointed data. You will organize and clean this data in order to perform basic statistical analysis.
# - In the real world, data is messy and/or disjointed
# - It is important to understand how to go through datasets and turn them into something more useful.
#
#
# - In this assignment, you are given 2 lists. One is a list of names, the other is a list of scores. Each name corresponds to a score with a same index. This represents a group of test scores of a 5 week period. Each person has 5 scores associated with them.
#     - Ex: 'Hal' scored a 50, 65, 70, 62, and 80. over the 5 week period.
#
#
# - **For each of the exersizes, you CANNOT hard-code the results. Your code must be dynamic. As in if more scores and names were added (while maintaining the same index matching structure), your code would work without changes.**
#
#
# - **Your job is to combine this data into a dictionary and perform various calculations to observe statistical trends in the data. Here are the steps required:**
#
#
# - **1) To begin, create a dictionary where each name is mapped to a list of their scores.**
#     - Ex: 'Hal': [50, 65, 70, 62, 80]
#     - To achieve this:
#         - Create an empty dictionary that will hold the name score mappings
#         - Use enumerate() to iterate through names using indexes and values
#             - If the name does not exist in the dictionary, assign a dictionary entry using the name as the key, and a list containing a list with the first score as an entry.
#             - If the name already exists in the dictionary, then append the correct score to the correct key in the dictionary.
#         - Print the dictionary as shown in the sample output
#             - print "Name : Score Dictionary"
#             - Under that, put the name of the dictionary not in a print statement
#             - If this is the last statement in a cell, it will output what is contained in the dictionary in the vertical format the sample output shows
#     - Before you move onto the next step, check that your dictionary is correct
#
#
# - **2) Create a name : mean score dictionary**
#     - Ex: 'Hal' : 65.4
#     - To achieve this:
#         - Create an empty dictionary that will hold the name : mean score combinations
#         - Iterate through the name : scores dictionary
#             - Assign the name to the mean of the scores in the name : mean score dictionary.
#         - Print the dictionary the same way as the first, matching the sample output
#
#
# - **3) Find the highest and lowest mean dynamically**
#     - Ex: See sample output
#     - To achieve this:
#         - Create variables maxValue and minValue set to 0 and 100 respectively.
#         - Create variables maxName and minName set to empty strings ("")
#         - Iterate through name : mean score dictionary
#             - if the mean is higher than our maxValue
#                 - Assign maxValue to the mean, and maxName to the name
#             - if the mean is lower than our minValue
#                 - Assign minValue to the mean, and minName to the name
#         - Print the values as shown in the sample output
#
#
# - **4) Create a name : score variation dictionary**
#     - Ex: 'Hal' : 30
#     - To achieve this:
#         - Create an empty dictionary that will hold the name : score variation combinations
#         - Iterate through the name : scores dicitonary
#             - Assign the name to the difference between the highest and lowest score for the person in the variation dictionary
#         - Print the dictionary the same way as the first, matching the sample output
#
#
# - **5) Find the highest and lowest variation dynamically**
#     - Ex: See sample output
#     - To achieve this:
#         - Create variables maxVariation and minVariation set to 0 and 100 respectively.
#         - Create variables maxName and minName set to empty strings ("")
#         - Iterate through name : mean score dictionary
#             - if the variation is higher than our maxValue
#                 - Assign maxVariation to the mean, and maxName to the name
#             - if the variation is lower than our minValue
#                 - Assign minVariation to the var, and minName to the name
#         - Print the values as shown in the sample output

# %%
#Data
names = ['Hal', 'Malcolm', 'Reese', 'Lois', 'Francis', 'Dewey', 'Caroline', 'Stevie','Craig',
         'Hal','Malcolm', 'Reese', 'Lois', 'Francis', 'Dewey', 'Caroline', 'Stevie','Craig',
         'Hal','Malcolm', 'Reese', 'Lois', 'Francis', 'Dewey', 'Caroline', 'Stevie','Craig',
         'Hal','Malcolm', 'Reese', 'Lois', 'Francis', 'Dewey', 'Caroline', 'Stevie','Craig',
         'Hal','Malcolm', 'Reese', 'Lois', 'Francis', 'Dewey', 'Caroline', 'Stevie','Craig']
scores = [50, 90, 25, 80, 60, 50, 90, 95, 70,
          65, 95, 20, 81, 65, 60, 91, 95, 73,
          70, 99, 0, 82, 80, 70, 85, 96, 74,
          62, 98, 40, 83, 90, 80, 94, 97, 66,
          80, 95, 30, 84, 60, 90, 99, 90, 60]

# %% [markdown]
#     Name : Score Dictionary
#
#     {'Hal': [50, 65, 70, 62, 80],
#      'Malcolm': [90, 95, 99, 98, 95],
#      'Reese': [25, 20, 0, 40, 30],
#      'Lois': [80, 81, 82, 83, 84],
#      'Francis': [60, 65, 80, 90, 60],
#      'Dewey': [50, 60, 70, 80, 90],
#      'Caroline': [90, 91, 85, 94, 99],
#      'Stevie': [95, 95, 96, 97, 90],
#      'Craig': [70, 73, 74, 66, 60]}
#
#     Name: Mean Dictionary
#
#     {'Hal': 65.4,
#      'Malcolm': 95.4,
#      'Reese': 23.0,
#      'Lois': 82.0,
#      'Francis': 71.0,
#      'Dewey': 70.0,
#      'Caroline': 91.8,
#      'Stevie': 94.6,
#      'Craig': 68.6}
#
#     Best Average Score: Malcolm, 95.4
#     Worst Average Score: Reese, 23.0
#
#     Name: Score Variation Dictionary
#
#     {'Hal': 30,
#      'Malcolm': 9,
#      'Reese': 40,
#      'Lois': 4,
#      'Francis': 30,
#      'Dewey': 40,
#      'Caroline': 14,
#      'Stevie': 7,
#      'Craig': 14}
#
#      Highest Score Variation: Reese, 40
#      Lowest Score Variation: Lois, 4
